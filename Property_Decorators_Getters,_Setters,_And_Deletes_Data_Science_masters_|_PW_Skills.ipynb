# %% [markdown]
# <a href="https://colab.research.google.com/github/sajan122/Class/blob/main/Property_Decorators_Getters%2C_Setters%2C_And_Deletes_Data_Science_masters_%7C_PW_Skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class pwskills:
    def __init__(self,course_name,course_price):
        self.course_name = course_name
        self.__course_price = course_price

    @property
    def course_price_access(self): #getter ka kam kar raha hai
        return self.__course_price #property hamesa getter kam kare gaa

    @course_price_access.setter
    def course_price_set(self,price):
        if price <= 3500:
            pass
        else:
            self.__course_price = price

    @course_price_access.deleter
    def course_price_delet(self):
        del self.__course_price

# %%
pw = pwskills('data sacience',3500)

# %%
pw.course_price_access
# Out:
# 3500

# %%
pw.course_price_set = 5000

# %%
pw.course_price_access
# Out:
# 5000

# %%
pw._pwskills__course_price
# Out:
# 5000

# %%
del pw.course_price_delet

# %%
pw.course_price_access
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-148702304.py in <cell line: 0>()
# ----> 1 pw.course_price_access
#
# /tmp/ipython-input-1668471819.py in course_price_access(self)
#       6     @property
#       7     def course_price_access(self): #getter ka kam kar raha hai
# ----> 8         return self.__course_price #property hamesa getter kam kare gaa
#       9
#      10     @course_price_access.setter
#
# AttributeError: 'pwskills' object has no attribute '_pwskills__course_price'

# %%
pw.course_name
# Out:
# 'data sacience'

# %%
pw.__course_price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-158291008.py in <cell line: 0>()
# ----> 1 pw.__course_price
#
# AttributeError: 'pwskills' object has no attribute '__course_price'

# %%
del pw.course_name

# %%
pw.course_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1723167898.py in <cell line: 0>()
# ----> 1 pw.course_name
#
# AttributeError: 'pwskills' object has no attribute 'course_name'
