# %% [markdown]
# <a href="https://colab.research.google.com/github/sajan122/Class/blob/main/Exceptions_Handling_With_Try_Except_Data_Science_masters_%7C_PW_Skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-4102073204.py in <cell line: 0>()
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
f = open("text.txt",'r')
print("this is my except")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4116604688.py in <cell line: 0>()
# ----> 1 f = open("text.txt",'r')
#       2 print("this is my except")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text.txt'

# %%
try:
    f = open("text.txt",'r')

except Exception as e :
    print("this is my except block" , e)
# Out:
# this is my except block [Errno 2] No such file or directory: 'text.txt'

# %%
try:
    f = open("text1.txt",'w')
    f.write("this will be excute code")
    f.close()

except Exception as e :
    print("this is my except block" , e)

# %%
try:
    f = open("text2.txt",'w')
    f.write("this will be excute code")


except Exception as e :
    print("this is my except block" , e)

else:
    f.close()
    print("this is my close run")
# Out:
# this is my close run

# %%
try:
    f = open("text3.txt",'r')
    f.write("this will be excute code")


except Exception as e :
    print("this is my except block" , e)

else:
    f.close()
    print("this is my close run")
# Out:
# this is my except block [Errno 2] No such file or directory: 'text3.txt'

# %%
try:
    f = open("text4.txt",'w')
    f.write("this will be excute code")
    f.close()

finally:
    print("finally will be excute any situation")
# Out:
# finally will be excute any situation

# %%
try:
    f = open("text5.txt",'r')
    f.write("this will be excute code")
    f.close()

finally:
    print("finally will be excute any situation")
# Out:
# finally will be excute any situation
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2095833508.py in <cell line: 0>()
#       1 try:
# ----> 2     f = open("text5.txt",'r')
#       3     f.write("this will be excute code")
#       4     f.close()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text5.txt'

# %%
try:
    a  = 10
    b  = int(input("enter number"))

    print(a/b)
except Exception as e:

    print("this is not possible")



else:
    print("this is  possible")
    print(a/b)
# Out:
# enter number5
# 2.0
# this is  possible
# 2.0

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
int('5')
# Out:
# 5

# %%
str(5)
# Out:
# '5'

# %%
"5"
# Out:
# '5'

# %%
f"{5}"
# Out:
# '5'

# %%
"5" / "5"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-559734277.py in <cell line: 0>()
# ----> 1 "5" / "5"
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
